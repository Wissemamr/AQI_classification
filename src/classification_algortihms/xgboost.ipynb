# %%
import pandas as pd
df = pd.read_csv('../../data/preprocessed_AQI_data.csv')
df.head()
# Out:
#    Country   City  AQI Value  AQI Category  CO AQI Value  CO AQI Category  \
# 0      130  10126         51             2             1                0
# 1       22  10140         41             0             1                0
# 2       75  10163         66             2             1                0
# 3      123  10185         34             0             1                0
# 4      166  10243         54             2             1                0
#
#    Ozone AQI Value  Ozone AQI Category  NO2 AQI Value  NO2 AQI Category  \
# 0               36                   0              0                 0
# 1                5                   0              1                 0
# 2               39                   0              2                 0
# 3               34                   0              0                 0
# 4               14                   0             11                 0
#
#    PM2.5 AQI Value  PM2.5 AQI Category      lat      lng
# 0               51                   2  44.7444  44.2031
# 1               41                   0  -5.2900 -44.4900
# 2               66                   2  37.1667  15.1833
# 3               20                   0  53.0167  20.8833
# 4               54                   2  16.1005 -88.8074

# %%
from sklearn.model_selection import train_test_split

# shuffle the data before splitting
df_shuffled = df.sample(frac=1, random_state=19)  
X = df_shuffled.drop(["AQI Category"], axis=1)
y = df_shuffled["AQI Category"]
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.8, random_state=22
)
print(X_train.shape, X_test.shape)
print(y_train.shape, y_test.shape)
# Out:
# (2845, 13) (11384, 13)
# (2845,) (11384,)

# %%
# %pip install xgboost
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: xgboost in /home/wissem/.local/lib/python3.10/site-packages (2.0.3)
# Requirement already satisfied: numpy in /home/wissem/.local/lib/python3.10/site-packages (from xgboost) (1.26.4)
# Requirement already satisfied: scipy in /home/wissem/.local/lib/python3.10/site-packages (from xgboost) (1.12.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score

model = XGBClassifier()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.9992972593113141

# %%
print(model.get_params())
# Out:
# {'objective': 'multi:softprob', 'base_score': None, 'booster': None, 'callbacks': None, 'colsample_bylevel': None, 'colsample_bynode': None, 'colsample_bytree': None, 'device': None, 'early_stopping_rounds': None, 'enable_categorical': False, 'eval_metric': None, 'feature_types': None, 'gamma': None, 'grow_policy': None, 'importance_type': None, 'interaction_constraints': None, 'learning_rate': None, 'max_bin': None, 'max_cat_threshold': None, 'max_cat_to_onehot': None, 'max_delta_step': None, 'max_depth': None, 'max_leaves': None, 'min_child_weight': None, 'missing': nan, 'monotone_constraints': None, 'multi_strategy': None, 'n_estimators': None, 'n_jobs': None, 'num_parallel_tree': None, 'random_state': None, 'reg_alpha': None, 'reg_lambda': None, 'sampling_method': None, 'scale_pos_weight': None, 'subsample': None, 'tree_method': None, 'validate_parameters': None, 'verbosity': None}

# %%
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, roc_auc_score
import seaborn as sns
import matplotlib.pyplot as plt

# Confusion Matrix
conf_matrix = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(conf_matrix)

sns.heatmap(conf_matrix, annot=True, cmap='Blues', fmt='g')
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
# Out:
# Confusion Matrix:
# [[5301    0    0    0    0    0]
#  [   0   41    0    0    0    0]
#  [   0    0 4741    0    0    0]
#  [   0    0    0  618    0    0]
#  [   0    0    0    0  588    0]
#  [   0    0    0    8    0   87]]

# %%
# Classification Report
print("\nClassification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      5301
#            1       1.00      1.00      1.00        41
#            2       1.00      1.00      1.00      4741
#            3       0.99      1.00      0.99       618
#            4       1.00      1.00      1.00       588
#            5       1.00      0.92      0.96        95
#
#     accuracy                           1.00     11384
#    macro avg       1.00      0.99      0.99     11384
# weighted avg       1.00      1.00      1.00     11384

# %%
# hyperparams tuning
from sklearn.model_selection import GridSearchCV

param_grid = {
    'n_estimators': [100, 200, 300],
    'max_depth': [3, 5, 7],
    'learning_rate': [0.01, 0.05, 0.1],
    'subsample': [0.5, 0.75, 1],
    'colsample_bytree': [0.5, 0.75, 1]
}

model = XGBClassifier()
grid_search = GridSearchCV(estimator=model, param_grid=param_grid, cv=3, n_jobs=-1, verbose=2)
grid_search.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 243 candidates, totalling 729 fits
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.5; total time=   0.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.5; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=3, n_estimators=100, subsample=1; total time=   0.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=3, n_estimators=100, subsample=1; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.75; total time=   0.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.75; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.75; total time=   0.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.5; total time=   0.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=3, n_estimators=100, subsample=1; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=3, n_estimators=200, subsample=0.5; total time=   0.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=3, n_estimators=200, subsample=0.5; total time=   0.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=3, n_estimators=200, subsample=0.5; total time=   0.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=3, n_estimators=200, subsample=0.75; total time=   0.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=3, n_estimators=200, subsample=0.75; total time=   0.5s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=3, n_estimators=200, subsample=0.75; total time=   0.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=3, n_estimators=200, subsample=1; total time=   0.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=3, n_estimators=200, subsample=1; total time=   0.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=3, n_estimators=200, subsample=1; total time=   0.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=3, n_estimators=300, subsample=0.5; total time=   0.5s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=3, n_estimators=300, subsample=0.5; total time=   0.6s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=3, n_estimators=300, subsample=0.5; total time=   0.5s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=3, n_estimators=300, subsample=0.75; total time=   0.5s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=3, n_estimators=300, subsample=0.75; total time=   0.5s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=3, n_estimators=300, subsample=0.75; total time=   0.6s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=3, n_estimators=300, subsample=1; total time=   0.5s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.5; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.5; total time=   0.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.75; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.75; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.5; total time=   0.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.75; total time=   0.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=3, n_estimators=300, subsample=1; total time=   0.5s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=5, n_estimators=100, subsample=1; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=5, n_estimators=100, subsample=1; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=5, n_estimators=100, subsample=1; total time=   0.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=3, n_estimators=300, subsample=1; total time=   0.9s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=5, n_estimators=200, subsample=0.5; total time=   0.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=5, n_estimators=200, subsample=0.5; total time=   0.5s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=5, n_estimators=200, subsample=0.75; total time=   0.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=5, n_estimators=200, subsample=0.5; total time=   0.5s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=5, n_estimators=200, subsample=0.75; total time=   0.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=5, n_estimators=200, subsample=0.75; total time=   0.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=5, n_estimators=200, subsample=1; total time=   0.5s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=5, n_estimators=200, subsample=1; total time=   0.6s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=5, n_estimators=200, subsample=1; total time=   0.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=5, n_estimators=300, subsample=0.5; total time=   0.6s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=5, n_estimators=300, subsample=0.75; total time=   0.6s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=5, n_estimators=300, subsample=0.5; total time=   0.8s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=5, n_estimators=300, subsample=0.5; total time=   0.8s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=5, n_estimators=300, subsample=0.75; total time=   0.6s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=5, n_estimators=300, subsample=0.75; total time=   0.7s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=7, n_estimators=100, subsample=0.5; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=7, n_estimators=100, subsample=0.5; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=7, n_estimators=100, subsample=0.75; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=7, n_estimators=100, subsample=0.75; total time=   0.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=5, n_estimators=300, subsample=1; total time=   0.7s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=7, n_estimators=100, subsample=1; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=7, n_estimators=100, subsample=0.75; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=7, n_estimators=100, subsample=0.5; total time=   0.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=5, n_estimators=300, subsample=1; total time=   0.6s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=7, n_estimators=100, subsample=1; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=7, n_estimators=100, subsample=1; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=5, n_estimators=300, subsample=1; total time=   1.0s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=7, n_estimators=200, subsample=0.5; total time=   0.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=7, n_estimators=200, subsample=0.5; total time=   0.6s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=7, n_estimators=200, subsample=0.5; total time=   0.5s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=7, n_estimators=200, subsample=0.75; total time=   0.5s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=7, n_estimators=200, subsample=1; total time=   0.5s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=7, n_estimators=200, subsample=0.75; total time=   0.6s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=7, n_estimators=200, subsample=1; total time=   0.5s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=7, n_estimators=200, subsample=0.75; total time=   0.7s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=7, n_estimators=200, subsample=1; total time=   0.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=7, n_estimators=300, subsample=0.5; total time=   0.7s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=7, n_estimators=300, subsample=0.5; total time=   0.6s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=7, n_estimators=300, subsample=0.5; total time=   0.7s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=7, n_estimators=300, subsample=0.75; total time=   0.7s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=7, n_estimators=300, subsample=0.75; total time=   0.7s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=3, n_estimators=100, subsample=0.5; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=3, n_estimators=100, subsample=0.5; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=7, n_estimators=300, subsample=1; total time=   0.6s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=3, n_estimators=100, subsample=0.5; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=7, n_estimators=300, subsample=0.75; total time=   0.9s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=7, n_estimators=300, subsample=1; total time=   0.8s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=3, n_estimators=100, subsample=0.75; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=3, n_estimators=100, subsample=0.75; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=3, n_estimators=100, subsample=1; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=3, n_estimators=100, subsample=0.75; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=3, n_estimators=100, subsample=1; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=3, n_estimators=100, subsample=1; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=7, n_estimators=300, subsample=1; total time=   0.6s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=3, n_estimators=200, subsample=0.5; total time=   0.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=3, n_estimators=200, subsample=0.5; total time=   0.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=3, n_estimators=200, subsample=0.5; total time=   0.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=3, n_estimators=200, subsample=0.75; total time=   0.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=3, n_estimators=200, subsample=1; total time=   0.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=3, n_estimators=200, subsample=0.75; total time=   0.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=3, n_estimators=200, subsample=1; total time=   0.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=3, n_estimators=200, subsample=0.75; total time=   0.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=3, n_estimators=200, subsample=1; total time=   0.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=3, n_estimators=300, subsample=0.5; total time=   0.5s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=3, n_estimators=300, subsample=0.5; total time=   0.5s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=3, n_estimators=300, subsample=0.75; total time=   0.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=3, n_estimators=300, subsample=0.75; total time=   0.5s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=3, n_estimators=300, subsample=0.75; total time=   0.5s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=3, n_estimators=300, subsample=1; total time=   0.5s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=3, n_estimators=300, subsample=0.5; total time=   0.6s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=100, subsample=0.5; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=100, subsample=0.5; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=100, subsample=0.5; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=3, n_estimators=300, subsample=1; total time=   0.5s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=100, subsample=0.75; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=100, subsample=0.75; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=100, subsample=0.75; total time=   0.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=100, subsample=1; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=3, n_estimators=300, subsample=1; total time=   0.5s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=100, subsample=1; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=100, subsample=1; total time=   0.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=200, subsample=0.5; total time=   0.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=200, subsample=0.5; total time=   0.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=200, subsample=0.5; total time=   0.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=200, subsample=0.75; total time=   0.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=200, subsample=0.75; total time=   0.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=200, subsample=0.75; total time=   0.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=200, subsample=1; total time=   0.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=200, subsample=1; total time=   0.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=200, subsample=1; total time=   0.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=300, subsample=0.5; total time=   0.5s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=300, subsample=0.75; total time=   0.5s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=300, subsample=0.5; total time=   0.5s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=300, subsample=0.5; total time=   0.6s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=300, subsample=0.75; total time=   0.5s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=300, subsample=0.75; total time=   0.5s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=7, n_estimators=100, subsample=0.5; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=300, subsample=1; total time=   0.5s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=7, n_estimators=100, subsample=0.5; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=7, n_estimators=100, subsample=0.5; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=300, subsample=1; total time=   0.5s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=7, n_estimators=100, subsample=0.75; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=7, n_estimators=100, subsample=0.75; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=7, n_estimators=100, subsample=0.75; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=7, n_estimators=100, subsample=1; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=300, subsample=1; total time=   0.5s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=7, n_estimators=100, subsample=1; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=7, n_estimators=100, subsample=1; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=7, n_estimators=200, subsample=0.5; total time=   0.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=7, n_estimators=200, subsample=0.5; total time=   0.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=7, n_estimators=200, subsample=0.5; total time=   0.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=7, n_estimators=200, subsample=0.75; total time=   0.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=7, n_estimators=200, subsample=0.75; total time=   0.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=7, n_estimators=200, subsample=0.75; total time=   0.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=7, n_estimators=200, subsample=1; total time=   0.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=7, n_estimators=200, subsample=1; total time=   0.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=7, n_estimators=200, subsample=1; total time=   0.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=7, n_estimators=300, subsample=0.5; total time=   0.5s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=7, n_estimators=300, subsample=0.5; total time=   0.6s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=7, n_estimators=300, subsample=0.75; total time=   0.6s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=7, n_estimators=300, subsample=0.75; total time=   0.6s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.5; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=7, n_estimators=300, subsample=0.5; total time=   0.8s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=7, n_estimators=300, subsample=0.75; total time=   0.7s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=7, n_estimators=300, subsample=1; total time=   0.6s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=7, n_estimators=300, subsample=1; total time=   0.5s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.5; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=7, n_estimators=300, subsample=1; total time=   0.7s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.75; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.5; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.75; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.75; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=3, n_estimators=100, subsample=1; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=3, n_estimators=100, subsample=1; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=3, n_estimators=100, subsample=1; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=3, n_estimators=200, subsample=0.5; total time=   0.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=3, n_estimators=200, subsample=0.5; total time=   0.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=3, n_estimators=200, subsample=0.5; total time=   0.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=3, n_estimators=200, subsample=0.75; total time=   0.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=3, n_estimators=200, subsample=0.75; total time=   0.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=3, n_estimators=200, subsample=0.75; total time=   0.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=3, n_estimators=200, subsample=1; total time=   0.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=3, n_estimators=200, subsample=1; total time=   0.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=3, n_estimators=200, subsample=1; total time=   0.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=3, n_estimators=300, subsample=0.5; total time=   0.5s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=3, n_estimators=300, subsample=0.5; total time=   0.5s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=3, n_estimators=300, subsample=0.75; total time=   0.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=3, n_estimators=300, subsample=0.75; total time=   0.5s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=3, n_estimators=300, subsample=0.5; total time=   0.5s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=100, subsample=0.5; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=3, n_estimators=300, subsample=1; total time=   0.5s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=100, subsample=0.5; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=100, subsample=0.5; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=3, n_estimators=300, subsample=0.75; total time=   0.6s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=100, subsample=0.75; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=3, n_estimators=300, subsample=1; total time=   0.6s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=100, subsample=1; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=100, subsample=0.75; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=3, n_estimators=300, subsample=1; total time=   0.5s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=100, subsample=0.75; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=100, subsample=1; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=100, subsample=1; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=200, subsample=0.5; total time=   0.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=200, subsample=0.75; total time=   0.4s[CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=200, subsample=0.5; total time=   0.4s
#
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=200, subsample=0.5; total time=   0.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=200, subsample=0.75; total time=   0.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=200, subsample=0.75; total time=   0.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=200, subsample=1; total time=   0.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=200, subsample=1; total time=   0.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=200, subsample=1; total time=   0.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=300, subsample=0.5; total time=   0.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=300, subsample=0.5; total time=   0.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=300, subsample=0.5; total time=   0.5s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=300, subsample=0.75; total time=   0.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=300, subsample=1; total time=   0.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=300, subsample=0.75; total time=   0.5s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=300, subsample=0.75; total time=   0.5s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=7, n_estimators=100, subsample=0.5; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=7, n_estimators=100, subsample=0.5; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=7, n_estimators=100, subsample=0.5; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=300, subsample=1; total time=   0.5s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=7, n_estimators=100, subsample=0.75; total time=   0.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=300, subsample=1; total time=   0.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=7, n_estimators=100, subsample=1; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=7, n_estimators=100, subsample=0.75; total time=   0.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=7, n_estimators=100, subsample=1; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=7, n_estimators=100, subsample=1; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=7, n_estimators=100, subsample=0.75; total time=   0.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=7, n_estimators=200, subsample=0.5; total time=   0.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=7, n_estimators=200, subsample=0.75; total time=   0.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=7, n_estimators=200, subsample=0.5; total time=   0.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=7, n_estimators=200, subsample=1; total time=   0.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=7, n_estimators=200, subsample=0.5; total time=   0.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=7, n_estimators=200, subsample=0.75; total time=   0.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=7, n_estimators=200, subsample=0.75; total time=   0.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=7, n_estimators=200, subsample=1; total time=   0.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=7, n_estimators=200, subsample=1; total time=   0.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=7, n_estimators=300, subsample=0.75; total time=   0.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=7, n_estimators=300, subsample=0.5; total time=   0.5s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=7, n_estimators=300, subsample=0.5; total time=   0.5s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=7, n_estimators=300, subsample=0.5; total time=   0.5s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=7, n_estimators=300, subsample=0.75; total time=   0.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=7, n_estimators=300, subsample=0.75; total time=   0.5s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=7, n_estimators=300, subsample=1; total time=   0.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=7, n_estimators=300, subsample=1; total time=   0.5s
# [CV] END colsample_bytree=0.75, learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.5; total time=   0.2s
# [CV] END colsample_bytree=0.75, learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.5; total time=   0.2s
# [CV] END colsample_bytree=0.75, learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.5; total time=   0.2s
# [CV] END colsample_bytree=0.75, learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.75; total time=   0.2s
# [CV] END colsample_bytree=0.75, learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.75; total time=   0.2s
# [CV] END colsample_bytree=0.75, learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.75; total time=   0.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=7, n_estimators=300, subsample=1; total time=   0.4s
# [CV] END colsample_bytree=0.75, learning_rate=0.01, max_depth=3, n_estimators=100, subsample=1; total time=   0.2s
# [CV] END colsample_bytree=0.75, learning_rate=0.01, max_depth=3, n_estimators=100, subsample=1; total time=   0.3s
# [CV] END colsample_bytree=0.75, learning_rate=0.01, max_depth=3, n_estimators=100, subsample=1; total time=   0.3s
# [CV] END colsample_bytree=0.75, learning_rate=0.01, max_depth=3, n_estimators=200, subsample=0.5; total time=   0.4s
# [CV] END colsample_bytree=0.75, learning_rate=0.01, max_depth=3, n_estimators=200, subsample=0.5; total time=   0.5s
# [CV] END colsample_bytree=0.75, learning_rate=0.01, max_depth=3, n_estimators=200, subsample=0.5; total time=   0.5s
# [CV] END colsample_bytree=0.75, learning_rate=0.01, max_depth=3, n_estimators=200, subsample=0.75; total time=   0.5s
# [CV] END colsample_bytree=0.75, learning_rate=0.01, max_depth=3, n_estimators=200, subsample=0.75; total time=   0.4s
# [CV] END colsample_bytree=0.75, learning_rate=0.01, max_depth=3, n_estimators=200, subsample=1; total time=   0.4s
# [CV] END colsample_bytree=0.75, learning_rate=0.01, max_depth=3, n_estimators=200, subsample=0.75; total time=   0.5s
# [CV] END colsample_bytree=0.75, learning_rate=0.01, max_depth=3, n_estimators=200, subsample=1; total time=   0.5s
# [CV] END colsample_bytree=0.75, learning_rate=0.01, max_depth=3, n_estimators=200, subsample=1; total time=   0.4s
# [CV] END colsample_bytree=0.75, learning_rate=0.01, max_depth=3, n_estimators=300, subsample=0.5; total time=   0.7s
# [CV] END colsample_bytree=0.75, learning_rate=0.01, max_depth=3, n_estimators=300, subsample=0.5; total time=   0.7s
# [CV] END colsample_bytree=0.75, learning_rate=0.01, max_depth=3, n_estimators=300, subsample=0.5; total time=   0.7s
# [CV] END colsample_bytree=0.75, learning_rate=0.01, max_depth=3, n_estimators=300, subsample=0.75; total time=   0.7s
# [CV] END colsample_bytree=0.75, learning_rate=0.01, max_depth=3, n_estimators=300, subsample=1; total time=   0.6s
# [CV] END colsample_bytree=0.75, learning_rate=0.01, max_depth=3, n_estimators=300, subsample=1; total time=   0.7s
# [CV] END colsample_bytree=0.75, learning_rate=0.01, max_depth=3, n_estimators=300, subsample=0.75; total time=   0.8s
# [CV] END colsample_bytree=0.75, learning_rate=0.01, max_depth=3, n_estimators=300, subsample=0.75; total time=   0.8s
# [CV] END colsample_bytree=0.75, learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.5; total time=   0.3s
# [CV] END colsample_bytree=0.75, learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.5; total time=   0.2s
# [CV] END colsample_bytree=0.75, learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.5; total time=   0.3s
# [CV] END colsample_bytree=0.75, learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.75; total time=   0.3s
# [CV] END colsample_bytree=0.75, learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.75; total time=   0.3s
# [CV] END colsample_bytree=0.75, learning_rate=0.01, max_depth=5, n_estimators=100, subsample=1; total time=   0.2s
# [CV] END colsample_bytree=0.75, learning_rate=0.01, max_depth=5, n_estimators=100, subsample=1; total time=   0.2s[CV] END colsample_bytree=0.75, learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.75; total time=   0.3s
#
# [CV] END colsample_bytree=0.75, learning_rate=0.01, max_depth=5, n_estimators=100, subsample=1; total time=   0.2s
# [CV] END colsample_bytree=0.75, learning_rate=0.01, max_depth=3, n_estimators=300, subsample=1; total time=   0.7s
# [CV] END colsample_bytree=0.75, learning_rate=0.01, max_depth=5, n_estimators=200, subsample=0.5; total time=   0.4s
# [CV] END colsample_bytree=0.75, learning_rate=0.01, max_depth=5, n_estimators=200, subsample=0.5; total time=   0.5s
# [CV] END colsample_bytree=0.75, learning_rate=0.01, max_depth=5, n_estimators=200, subsample=0.5; total time=   0.5s
# [CV] END colsample_bytree=0.75, learning_rate=0.01, max_depth=5, n_estimators=200, subsample=0.75; total time=   0.4s
# [CV] END colsample_bytree=0.75, learning_rate=0.01, max_depth=5, n_estimators=200, subsample=1; total time=   0.4s
# [CV] END colsample_bytree=0.75, learning_rate=0.01, max_depth=5, n_estimators=200, subsample=1; total time=   0.4s
# [CV] END colsample_bytree=0.75, learning_rate=0.01, max_depth=5, n_estimators=200, subsample=0.75; total time=   0.5s
# [CV] END colsample_bytree=0.75, learning_rate=0.01, max_depth=5, n_estimators=200, subsample=0.75; total time=   0.6s
# [CV] END colsample_bytree=0.75, learning_rate=0.01, max_depth=5, n_estimators=200, subsample=1; total time=   0.5s
# [CV] END colsample_bytree=0.75, learning_rate=0.01, max_depth=5, n_estimators=300, subsample=0.5; total time=   0.7s
# [CV] END colsample_bytree=0.75, learning_rate=0.01, max_depth=5, n_estimators=300, subsample=0.5; total time=   0.7s
# [CV] END colsample_bytree=0.75, learning_rate=0.01, max_depth=5, n_estimators=300, subsample=0.75; total time=   0.7s
# [CV] END colsample_bytree=0.75, learning_rate=0.01, max_depth=5, n_estimators=300, subsample=0.75; total time=   0.7s
# [CV] END colsample_bytree=0.75, learning_rate=0.01, max_depth=5, n_estimators=300, subsample=0.5; total time=   0.8s
# [CV] END colsample_bytree=0.75, learning_rate=0.01, max_depth=7, n_estimators=100, subsample=0.5; total time=   0.2s
# [CV] END colsample_bytree=0.75, learning_rate=0.01, max_depth=5, n_estimators=300, subsample=0.75; total time=   0.8s
# [CV] END colsample_bytree=0.75, learning_rate=0.01, max_depth=7, n_estimators=100, subsample=0.5; total time=   0.2s
# [CV] END colsample_bytree=0.75, learning_rate=0.01, max_depth=7, n_estimators=100, subsample=0.5; total time=   0.2s
# [CV] END colsample_bytree=0.75, learning_rate=0.01, max_depth=7, n_estimators=100, subsample=0.75; total time=   0.2s
# [CV] END colsample_bytree=0.75, learning_rate=0.01, max_depth=5, n_estimators=300, subsample=1; total time=   0.9s
# [CV] END colsample_bytree=0.75, learning_rate=0.01, max_depth=5, n_estimators=300, subsample=1; total time=   0.7s
# [CV] END colsample_bytree=0.75, learning_rate=0.01, max_depth=7, n_estimators=100, subsample=0.75; total time=   0.3s
# [CV] END colsample_bytree=0.75, learning_rate=0.01, max_depth=7, n_estimators=100, subsample=0.75; total time=   0.3s
# [CV] END colsample_bytree=0.75, learning_rate=0.01, max_depth=7, n_estimators=100, subsample=1; total time=   0.2s
# [CV] END colsample_bytree=0.75, learning_rate=0.01, max_depth=7, n_estimators=100, subsample=1; total time=   0.3s
# [CV] END colsample_bytree=0.75, learning_rate=0.01, max_depth=7, n_estimators=100, subsample=1; total time=   0.3s
# [CV] END colsample_bytree=0.75, learning_rate=0.01, max_depth=5, n_estimators=300, subsample=1; total time=   0.7s
# [CV] END colsample_bytree=0.75, learning_rate=0.01, max_depth=7, n_estimators=200, subsample=0.5; total time=   0.4s
# [CV] END colsample_bytree=0.75, learning_rate=0.01, max_depth=7, n_estimators=200, subsample=0.5; total time=   0.4s
# [CV] END colsample_bytree=0.75, learning_rate=0.01, max_depth=7, n_estimators=200, subsample=0.5; total time=   0.5s
# [CV] END colsample_bytree=0.75, learning_rate=0.01, max_depth=7, n_estimators=200, subsample=0.75; total time=   0.5s
# [CV] END colsample_bytree=0.75, learning_rate=0.01, max_depth=7, n_estimators=200, subsample=0.75; total time=   0.6s
# [CV] END colsample_bytree=0.75, learning_rate=0.01, max_depth=7, n_estimators=200, subsample=0.75; total time=   0.5s
# [CV] END colsample_bytree=0.75, learning_rate=0.01, max_depth=7, n_estimators=200, subsample=1; total time=   0.5s
# [CV] END colsample_bytree=0.75, learning_rate=0.01, max_depth=7, n_estimators=200, subsample=1; total time=   0.5s
# [CV] END colsample_bytree=0.75, learning_rate=0.01, max_depth=7, n_estimators=200, subsample=1; total time=   0.5s
# [CV] END colsample_bytree=0.75, learning_rate=0.01, max_depth=7, n_estimators=300, subsample=0.5; total time=   0.6s
# [CV] END colsample_bytree=0.75, learning_rate=0.01, max_depth=7, n_estimators=300, subsample=0.5; total time=   0.8s
# [CV] END colsample_bytree=0.75, learning_rate=0.01, max_depth=7, n_estimators=300, subsample=0.5; total time=   0.9s
# [CV] END colsample_bytree=0.75, learning_rate=0.01, max_depth=7, n_estimators=300, subsample=0.75; total time=   0.7s
# [CV] END colsample_bytree=0.75, learning_rate=0.01, max_depth=7, n_estimators=300, subsample=0.75; total time=   0.8s
# [CV] END colsample_bytree=0.75, learning_rate=0.01, max_depth=7, n_estimators=300, subsample=0.75; total time=   0.9s
# [CV] END colsample_bytree=0.75, learning_rate=0.01, max_depth=7, n_estimators=300, subsample=1; total time=   0.8s
# [CV] END colsample_bytree=0.75, learning_rate=0.01, max_depth=7, n_estimators=300, subsample=1; total time=   0.6s
# [CV] END colsample_bytree=0.75, learning_rate=0.05, max_depth=3, n_estimators=100, subsample=0.75; total time=   0.3s
# [CV] END colsample_bytree=0.75, learning_rate=0.05, max_depth=3, n_estimators=100, subsample=0.5; total time=   0.3s
# [CV] END colsample_bytree=0.75, learning_rate=0.05, max_depth=3, n_estimators=100, subsample=0.5; total time=   0.4s
# [CV] END colsample_bytree=0.75, learning_rate=0.05, max_depth=3, n_estimators=100, subsample=0.5; total time=   0.3s
# [CV] END colsample_bytree=0.75, learning_rate=0.01, max_depth=7, n_estimators=300, subsample=1; total time=   0.8s
# [CV] END colsample_bytree=0.75, learning_rate=0.05, max_depth=3, n_estimators=100, subsample=0.75; total time=   0.2s
# [CV] END colsample_bytree=0.75, learning_rate=0.05, max_depth=3, n_estimators=100, subsample=0.75; total time=   0.2s
# [CV] END colsample_bytree=0.75, learning_rate=0.05, max_depth=3, n_estimators=100, subsample=1; total time=   0.2s
# [CV] END colsample_bytree=0.75, learning_rate=0.05, max_depth=3, n_estimators=100, subsample=1; total time=   0.2s
# [CV] END colsample_bytree=0.75, learning_rate=0.05, max_depth=3, n_estimators=100, subsample=1; total time=   0.2s
# [CV] END colsample_bytree=0.75, learning_rate=0.05, max_depth=3, n_estimators=200, subsample=0.75; total time=   0.4s
# [CV] END colsample_bytree=0.75, learning_rate=0.05, max_depth=3, n_estimators=200, subsample=0.5; total time=   0.4s
# [CV] END colsample_bytree=0.75, learning_rate=0.05, max_depth=3, n_estimators=200, subsample=0.5; total time=   0.4s
# [CV] END colsample_bytree=0.75, learning_rate=0.05, max_depth=3, n_estimators=200, subsample=0.75; total time=   0.4s
# [CV] END colsample_bytree=0.75, learning_rate=0.05, max_depth=3, n_estimators=200, subsample=0.5; total time=   0.5s
# [CV] END colsample_bytree=0.75, learning_rate=0.05, max_depth=3, n_estimators=200, subsample=1; total time=   0.3s
# [CV] END colsample_bytree=0.75, learning_rate=0.05, max_depth=3, n_estimators=200, subsample=0.75; total time=   0.4s
# [CV] END colsample_bytree=0.75, learning_rate=0.05, max_depth=3, n_estimators=200, subsample=1; total time=   0.5s
# [CV] END colsample_bytree=0.75, learning_rate=0.05, max_depth=3, n_estimators=200, subsample=1; total time=   0.3s
# [CV] END colsample_bytree=0.75, learning_rate=0.05, max_depth=3, n_estimators=300, subsample=0.5; total time=   0.5s
# [CV] END colsample_bytree=0.75, learning_rate=0.05, max_depth=3, n_estimators=300, subsample=0.5; total time=   0.6s
# [CV] END colsample_bytree=0.75, learning_rate=0.05, max_depth=3, n_estimators=300, subsample=0.5; total time=   0.6s
# [CV] END colsample_bytree=0.75, learning_rate=0.05, max_depth=3, n_estimators=300, subsample=0.75; total time=   0.5s
# [CV] END colsample_bytree=0.75, learning_rate=0.05, max_depth=3, n_estimators=300, subsample=0.75; total time=   0.6s
# [CV] END colsample_bytree=0.75, learning_rate=0.05, max_depth=3, n_estimators=300, subsample=0.75; total time=   0.5s
# [CV] END colsample_bytree=0.75, learning_rate=0.05, max_depth=3, n_estimators=300, subsample=1; total time=   0.6s
# [CV] END colsample_bytree=0.75, learning_rate=0.05, max_depth=5, n_estimators=100, subsample=0.5; total time=   0.3s
# [CV] END colsample_bytree=0.75, learning_rate=0.05, max_depth=5, n_estimators=100, subsample=0.75; total time=   0.2s
# [CV] END colsample_bytree=0.75, learning_rate=0.05, max_depth=5, n_estimators=100, subsample=0.5; total time=   0.3s
# [CV] END colsample_bytree=0.75, learning_rate=0.05, max_depth=5, n_estimators=100, subsample=0.5; total time=   0.3s
# [CV] END colsample_bytree=0.75, learning_rate=0.05, max_depth=5, n_estimators=100, subsample=0.75; total time=   0.2s
# [CV] END colsample_bytree=0.75, learning_rate=0.05, max_depth=3, n_estimators=300, subsample=1; total time=   0.6s
# [CV] END colsample_bytree=0.75, learning_rate=0.05, max_depth=3, n_estimators=300, subsample=1; total time=   0.5s
# [CV] END colsample_bytree=0.75, learning_rate=0.05, max_depth=5, n_estimators=100, subsample=1; total time=   0.3s
# [CV] END colsample_bytree=0.75, learning_rate=0.05, max_depth=5, n_estimators=100, subsample=1; total time=   0.2s
# [CV] END colsample_bytree=0.75, learning_rate=0.05, max_depth=5, n_estimators=100, subsample=1; total time=   0.2s
# [CV] END colsample_bytree=0.75, learning_rate=0.05, max_depth=5, n_estimators=100, subsample=0.75; total time=   0.3s
# [CV] END colsample_bytree=0.75, learning_rate=0.05, max_depth=5, n_estimators=200, subsample=0.5; total time=   0.4s
# [CV] END colsample_bytree=0.75, learning_rate=0.05, max_depth=5, n_estimators=200, subsample=0.5; total time=   0.4s
# [CV] END colsample_bytree=0.75, learning_rate=0.05, max_depth=5, n_estimators=200, subsample=0.5; total time=   0.4s
# [CV] END colsample_bytree=0.75, learning_rate=0.05, max_depth=5, n_estimators=200, subsample=0.75; total time=   0.4s
# [CV] END colsample_bytree=0.75, learning_rate=0.05, max_depth=5, n_estimators=200, subsample=1; total time=   0.4s
# [CV] END colsample_bytree=0.75, learning_rate=0.05, max_depth=5, n_estimators=200, subsample=0.75; total time=   0.5s
# [CV] END colsample_bytree=0.75, learning_rate=0.05, max_depth=5, n_estimators=200, subsample=1; total time=   0.5s
# [CV] END colsample_bytree=0.75, learning_rate=0.05, max_depth=5, n_estimators=200, subsample=1; total time=   0.4s
# [CV] END colsample_bytree=0.75, learning_rate=0.05, max_depth=5, n_estimators=200, subsample=0.75; total time=   0.6s
# [CV] END colsample_bytree=0.75, learning_rate=0.05, max_depth=5, n_estimators=300, subsample=0.5; total time=   0.5s
# [CV] END colsample_bytree=0.75, learning_rate=0.05, max_depth=5, n_estimators=300, subsample=0.5; total time=   0.6s
# [CV] END colsample_bytree=0.75, learning_rate=0.05, max_depth=5, n_estimators=300, subsample=0.5; total time=   0.5s
# [CV] END colsample_bytree=0.75, learning_rate=0.05, max_depth=5, n_estimators=300, subsample=1; total time=   0.5s
# [CV] END colsample_bytree=0.75, learning_rate=0.05, max_depth=7, n_estimators=100, subsample=0.5; total time=   0.2s
# [CV] END colsample_bytree=0.75, learning_rate=0.05, max_depth=7, n_estimators=100, subsample=0.5; total time=   0.2s
# [CV] END colsample_bytree=0.75, learning_rate=0.05, max_depth=5, n_estimators=300, subsample=0.75; total time=   0.6s
# [CV] END colsample_bytree=0.75, learning_rate=0.05, max_depth=5, n_estimators=300, subsample=0.75; total time=   0.6s
# [CV] END colsample_bytree=0.75, learning_rate=0.05, max_depth=5, n_estimators=300, subsample=1; total time=   0.5s
# [CV] END colsample_bytree=0.75, learning_rate=0.05, max_depth=5, n_estimators=300, subsample=0.75; total time=   0.6s
# [CV] END colsample_bytree=0.75, learning_rate=0.05, max_depth=7, n_estimators=100, subsample=0.5; total time=   0.2s
# [CV] END colsample_bytree=0.75, learning_rate=0.05, max_depth=7, n_estimators=100, subsample=1; total time=   0.2s
# [CV] END colsample_bytree=0.75, learning_rate=0.05, max_depth=7, n_estimators=100, subsample=1; total time=   0.2s
# [CV] END colsample_bytree=0.75, learning_rate=0.05, max_depth=7, n_estimators=100, subsample=0.75; total time=   0.3s
# [CV] END colsample_bytree=0.75, learning_rate=0.05, max_depth=5, n_estimators=300, subsample=1; total time=   0.6s
# [CV] END colsample_bytree=0.75, learning_rate=0.05, max_depth=7, n_estimators=100, subsample=1; total time=   0.3s
# [CV] END colsample_bytree=0.75, learning_rate=0.05, max_depth=7, n_estimators=100, subsample=0.75; total time=   0.3s
# [CV] END colsample_bytree=0.75, learning_rate=0.05, max_depth=7, n_estimators=100, subsample=0.75; total time=   0.4s
# [CV] END colsample_bytree=0.75, learning_rate=0.05, max_depth=7, n_estimators=200, subsample=0.5; total time=   0.4s
# [CV] END colsample_bytree=0.75, learning_rate=0.05, max_depth=7, n_estimators=200, subsample=0.5; total time=   0.4s
# [CV] END colsample_bytree=0.75, learning_rate=0.05, max_depth=7, n_estimators=200, subsample=0.75; total time=   0.4s
# [CV] END colsample_bytree=0.75, learning_rate=0.05, max_depth=7, n_estimators=200, subsample=0.75; total time=   0.4s
# [CV] END colsample_bytree=0.75, learning_rate=0.05, max_depth=7, n_estimators=200, subsample=0.75; total time=   0.5s
# [CV] END colsample_bytree=0.75, learning_rate=0.05, max_depth=7, n_estimators=200, subsample=1; total time=   0.4s
# [CV] END colsample_bytree=0.75, learning_rate=0.05, max_depth=7, n_estimators=200, subsample=0.5; total time=   0.5s
# [CV] END colsample_bytree=0.75, learning_rate=0.05, max_depth=7, n_estimators=200, subsample=1; total time=   0.5s
# [CV] END colsample_bytree=0.75, learning_rate=0.05, max_depth=7, n_estimators=200, subsample=1; total time=   0.4s
# [CV] END colsample_bytree=0.75, learning_rate=0.05, max_depth=7, n_estimators=300, subsample=0.5; total time=   0.6s
# [CV] END colsample_bytree=0.75, learning_rate=0.05, max_depth=7, n_estimators=300, subsample=0.5; total time=   0.6s
# [CV] END colsample_bytree=0.75, learning_rate=0.05, max_depth=7, n_estimators=300, subsample=0.5; total time=   0.5s
# [CV] END colsample_bytree=0.75, learning_rate=0.05, max_depth=7, n_estimators=300, subsample=0.75; total time=   0.6s
# [CV] END colsample_bytree=0.75, learning_rate=0.05, max_depth=7, n_estimators=300, subsample=0.75; total time=   0.6s
# [CV] END colsample_bytree=0.75, learning_rate=0.05, max_depth=7, n_estimators=300, subsample=0.75; total time=   0.6s
# [CV] END colsample_bytree=0.75, learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.5; total time=   0.2s
# [CV] END colsample_bytree=0.75, learning_rate=0.05, max_depth=7, n_estimators=300, subsample=1; total time=   0.6s
# [CV] END colsample_bytree=0.75, learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.5; total time=   0.3s
# [CV] END colsample_bytree=0.75, learning_rate=0.05, max_depth=7, n_estimators=300, subsample=1; total time=   0.6s
# [CV] END colsample_bytree=0.75, learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.5; total time=   0.3s
# [CV] END colsample_bytree=0.75, learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.75; total time=   0.3s
# [CV] END colsample_bytree=0.75, learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.75; total time=   0.3s
# [CV] END colsample_bytree=0.75, learning_rate=0.1, max_depth=3, n_estimators=100, subsample=1; total time=   0.2s
# [CV] END colsample_bytree=0.75, learning_rate=0.1, max_depth=3, n_estimators=100, subsample=1; total time=   0.3s
# [CV] END colsample_bytree=0.75, learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.75; total time=   0.3s
# [CV] END colsample_bytree=0.75, learning_rate=0.1, max_depth=3, n_estimators=100, subsample=1; total time=   0.3s
# ...
# [CV] END colsample_bytree=1, learning_rate=0.05, max_depth=5, n_estimators=100, subsample=1; total time=   0.3s
# [CV] END colsample_bytree=1, learning_rate=0.05, max_depth=5, n_estimators=100, subsample=1; total time=   0.3s
# [CV] END colsample_bytree=1, learning_rate=0.05, max_depth=5, n_estimators=200, subsample=0.5; total time=   0.5s
# [CV] END colsample_bytree=1, learning_rate=0.05, max_depth=5, n_estimators=200, subsample=0.5; total time=   0.4s
# [CV] END colsample_bytree=1, learning_rate=0.05, max_depth=5, n_estimators=200, subsample=0.5; total time=   0.5s
# [CV] END colsample_bytree=1, learning_rate=0.05, max_depth=5, n_estimators=200, subsample=0.75; total time=   0.4s
# [CV] END colsample_bytree=1, learning_rate=0.05, max_depth=5, n_estimators=200, subsample=0.75; total time=   0.4s
# [CV] END colsample_bytree=1, learning_rate=0.05, max_depth=5, n_estimators=200, subsample=0.75; total time=   0.5s
# [CV] END colsample_bytree=1, learning_rate=0.05, max_depth=5, n_estimators=200, subsample=1; total time=   0.5s
# [CV] END colsample_bytree=1, learning_rate=0.05, max_depth=5, n_estimators=200, subsample=1; total time=   0.4s
# [CV] END colsample_bytree=1, learning_rate=0.05, max_depth=5, n_estimators=200, subsample=1; total time=   0.6s
# [CV] END colsample_bytree=1, learning_rate=0.05, max_depth=5, n_estimators=300, subsample=0.5; total time=   0.6s
# [CV] END colsample_bytree=1, learning_rate=0.05, max_depth=5, n_estimators=300, subsample=0.5; total time=   0.6s
# [CV] END colsample_bytree=1, learning_rate=0.05, max_depth=5, n_estimators=300, subsample=0.5; total time=   0.6s
# [CV] END colsample_bytree=1, learning_rate=0.05, max_depth=5, n_estimators=300, subsample=0.75; total time=   0.7s
# [CV] END colsample_bytree=1, learning_rate=0.05, max_depth=5, n_estimators=300, subsample=0.75; total time=   0.7s
# [CV] END colsample_bytree=1, learning_rate=0.05, max_depth=5, n_estimators=300, subsample=0.75; total time=   0.7s
# [CV] END colsample_bytree=1, learning_rate=0.05, max_depth=7, n_estimators=100, subsample=0.5; total time=   0.3s
# [CV] END colsample_bytree=1, learning_rate=0.05, max_depth=7, n_estimators=100, subsample=0.5; total time=   0.3s
# [CV] END colsample_bytree=1, learning_rate=0.05, max_depth=5, n_estimators=300, subsample=1; total time=   0.6s
# [CV] END colsample_bytree=1, learning_rate=0.05, max_depth=7, n_estimators=100, subsample=0.5; total time=   0.3s
# [CV] END colsample_bytree=1, learning_rate=0.05, max_depth=5, n_estimators=300, subsample=1; total time=   0.7s
# [CV] END colsample_bytree=1, learning_rate=0.05, max_depth=5, n_estimators=300, subsample=1; total time=   0.5s
# [CV] END colsample_bytree=1, learning_rate=0.05, max_depth=7, n_estimators=100, subsample=0.75; total time=   0.3s
# [CV] END colsample_bytree=1, learning_rate=0.05, max_depth=7, n_estimators=100, subsample=1; total time=   0.2s
# [CV] END colsample_bytree=1, learning_rate=0.05, max_depth=7, n_estimators=100, subsample=0.75; total time=   0.3s
# [CV] END colsample_bytree=1, learning_rate=0.05, max_depth=7, n_estimators=100, subsample=0.75; total time=   0.3s
# [CV] END colsample_bytree=1, learning_rate=0.05, max_depth=7, n_estimators=100, subsample=1; total time=   0.4s
# [CV] END colsample_bytree=1, learning_rate=0.05, max_depth=7, n_estimators=100, subsample=1; total time=   0.3s
# [CV] END colsample_bytree=1, learning_rate=0.05, max_depth=7, n_estimators=200, subsample=0.5; total time=   0.4s
# [CV] END colsample_bytree=1, learning_rate=0.05, max_depth=7, n_estimators=200, subsample=0.5; total time=   0.5s
# [CV] END colsample_bytree=1, learning_rate=0.05, max_depth=7, n_estimators=200, subsample=0.5; total time=   0.5s
# [CV] END colsample_bytree=1, learning_rate=0.05, max_depth=7, n_estimators=200, subsample=0.75; total time=   0.5s
# [CV] END colsample_bytree=1, learning_rate=0.05, max_depth=7, n_estimators=200, subsample=1; total time=   0.5s
# [CV] END colsample_bytree=1, learning_rate=0.05, max_depth=7, n_estimators=200, subsample=0.75; total time=   0.6s
# [CV] END colsample_bytree=1, learning_rate=0.05, max_depth=7, n_estimators=200, subsample=1; total time=   0.5s
# [CV] END colsample_bytree=1, learning_rate=0.05, max_depth=7, n_estimators=200, subsample=0.75; total time=   0.6s
# [CV] END colsample_bytree=1, learning_rate=0.05, max_depth=7, n_estimators=200, subsample=1; total time=   0.4s
# [CV] END colsample_bytree=1, learning_rate=0.05, max_depth=7, n_estimators=300, subsample=0.5; total time=   0.6s
# [CV] END colsample_bytree=1, learning_rate=0.05, max_depth=7, n_estimators=300, subsample=0.5; total time=   0.6s
# [CV] END colsample_bytree=1, learning_rate=0.05, max_depth=7, n_estimators=300, subsample=0.5; total time=   0.7s
# [CV] END colsample_bytree=1, learning_rate=0.05, max_depth=7, n_estimators=300, subsample=0.75; total time=   0.6s
# [CV] END colsample_bytree=1, learning_rate=0.05, max_depth=7, n_estimators=300, subsample=1; total time=   0.5s
# [CV] END colsample_bytree=1, learning_rate=0.05, max_depth=7, n_estimators=300, subsample=1; total time=   0.7s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.5; total time=   0.2s
# [CV] END colsample_bytree=1, learning_rate=0.05, max_depth=7, n_estimators=300, subsample=0.75; total time=   0.7s
# [CV] END colsample_bytree=1, learning_rate=0.05, max_depth=7, n_estimators=300, subsample=0.75; total time=   0.8s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.5; total time=   0.2s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.5; total time=   0.3s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.75; total time=   0.2s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.75; total time=   0.2s
# [CV] END colsample_bytree=1, learning_rate=0.05, max_depth=7, n_estimators=300, subsample=1; total time=   0.6s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.75; total time=   0.2s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=3, n_estimators=100, subsample=1; total time=   0.2s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=3, n_estimators=100, subsample=1; total time=   0.2s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=3, n_estimators=100, subsample=1; total time=   0.3s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=3, n_estimators=200, subsample=0.5; total time=   0.4s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=3, n_estimators=200, subsample=0.5; total time=   0.4s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=3, n_estimators=200, subsample=0.75; total time=   0.4s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=3, n_estimators=200, subsample=0.75; total time=   0.4s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=3, n_estimators=200, subsample=0.5; total time=   0.5s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=3, n_estimators=200, subsample=1; total time=   0.4s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=3, n_estimators=200, subsample=0.75; total time=   0.4s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=3, n_estimators=200, subsample=1; total time=   0.4s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=3, n_estimators=200, subsample=1; total time=   0.3s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=3, n_estimators=300, subsample=0.5; total time=   0.6s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=3, n_estimators=300, subsample=0.5; total time=   0.6s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=3, n_estimators=300, subsample=0.5; total time=   0.6s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=3, n_estimators=300, subsample=0.75; total time=   0.6s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=3, n_estimators=300, subsample=0.75; total time=   0.6s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=3, n_estimators=300, subsample=0.75; total time=   0.6s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=3, n_estimators=300, subsample=1; total time=   0.5s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=3, n_estimators=300, subsample=1; total time=   0.6s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=5, n_estimators=100, subsample=0.5; total time=   0.2s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=5, n_estimators=100, subsample=0.5; total time=   0.3s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=5, n_estimators=100, subsample=0.5; total time=   0.3s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=5, n_estimators=100, subsample=0.75; total time=   0.2s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=5, n_estimators=100, subsample=0.75; total time=   0.3s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=3, n_estimators=300, subsample=1; total time=   0.5s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=5, n_estimators=100, subsample=1; total time=   0.2s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=5, n_estimators=100, subsample=1; total time=   0.3s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=5, n_estimators=100, subsample=0.75; total time=   0.4s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=5, n_estimators=100, subsample=1; total time=   0.2s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=5, n_estimators=200, subsample=0.5; total time=   0.4s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=5, n_estimators=200, subsample=0.5; total time=   0.4s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=5, n_estimators=200, subsample=0.75; total time=   0.4s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=5, n_estimators=200, subsample=0.5; total time=   0.4s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=5, n_estimators=200, subsample=0.75; total time=   0.4s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=5, n_estimators=200, subsample=1; total time=   0.4s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=5, n_estimators=200, subsample=0.75; total time=   0.4s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=5, n_estimators=200, subsample=1; total time=   0.5s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=5, n_estimators=200, subsample=1; total time=   0.3s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=5, n_estimators=300, subsample=0.5; total time=   0.5s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=5, n_estimators=300, subsample=0.5; total time=   0.5s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=5, n_estimators=300, subsample=0.75; total time=   0.5s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=5, n_estimators=300, subsample=0.75; total time=   0.5s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=5, n_estimators=300, subsample=0.75; total time=   0.6s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=5, n_estimators=300, subsample=1; total time=   0.5s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=7, n_estimators=100, subsample=0.5; total time=   0.2s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=5, n_estimators=300, subsample=0.5; total time=   0.7s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=7, n_estimators=100, subsample=0.5; total time=   0.2s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=5, n_estimators=300, subsample=1; total time=   0.6s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=7, n_estimators=100, subsample=0.5; total time=   0.2s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=7, n_estimators=100, subsample=0.75; total time=   0.2s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=7, n_estimators=100, subsample=0.75; total time=   0.2s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=7, n_estimators=100, subsample=0.75; total time=   0.3s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=5, n_estimators=300, subsample=1; total time=   0.5s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=7, n_estimators=100, subsample=1; total time=   0.3s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=7, n_estimators=100, subsample=1; total time=   0.4s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=7, n_estimators=100, subsample=1; total time=   0.4s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=7, n_estimators=200, subsample=0.5; total time=   0.5s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=7, n_estimators=200, subsample=0.5; total time=   0.4s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=7, n_estimators=200, subsample=0.5; total time=   0.4s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=7, n_estimators=200, subsample=0.75; total time=   0.4s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=7, n_estimators=200, subsample=0.75; total time=   0.4s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=7, n_estimators=200, subsample=0.75; total time=   0.5s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=7, n_estimators=200, subsample=1; total time=   0.4s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=7, n_estimators=200, subsample=1; total time=   0.4s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=7, n_estimators=200, subsample=1; total time=   0.4s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=7, n_estimators=300, subsample=0.5; total time=   0.5s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=7, n_estimators=300, subsample=0.5; total time=   0.6s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=7, n_estimators=300, subsample=0.75; total time=   0.5s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=7, n_estimators=300, subsample=0.75; total time=   0.5s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=7, n_estimators=300, subsample=0.5; total time=   0.6s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=7, n_estimators=300, subsample=1; total time=   0.5s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=7, n_estimators=300, subsample=0.75; total time=   0.5s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=7, n_estimators=300, subsample=1; total time=   0.4s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=7, n_estimators=300, subsample=1; total time=   0.3s
# GridSearchCV(cv=3,
#              estimator=XGBClassifier(base_score=None, booster=None,
#                                      callbacks=None, colsample_bylevel=None,
#                                      colsample_bynode=None,
#                                      colsample_bytree=None, device=None,
#                                      early_stopping_rounds=None,
#                                      enable_categorical=False, eval_metric=None,
#                                      feature_types=None, gamma=None,
#                                      grow_policy=None, importance_type=None,
#                                      interaction_constraints=None,
#                                      learning_rate=None,...
#                                      max_delta_step=None, max_depth=None,
#                                      max_leaves=None, min_child_weight=None,
#                                      missing=nan, monotone_constraints=None,
#                                      multi_strategy=None, n_estimators=None,
#                                      n_jobs=None, num_parallel_tree=None,
#                                      random_state=None, ...),
#              n_jobs=-1,
#              param_grid={'colsample_bytree': [0.5, 0.75, 1],
#                          'learning_rate': [0.01, 0.05, 0.1],
#                          'max_depth': [3, 5, 7],
#                          'n_estimators': [100, 200, 300],
#                          'subsample': [0.5, 0.75, 1]},
#              verbose=2)

# %%
print("Best Parameters:", grid_search.best_params_)
print("Best Score:", grid_search.best_score_)
# Out:
# Best Parameters: {'colsample_bytree': 0.5, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 200, 'subsample': 0.5}
# Best Score: 0.9996487530734107

# %%
model2 = XGBClassifier(**grid_search.best_params_)
model2.get_params()
# Out:
# {'objective': 'binary:logistic',
#  'base_score': None,
#  'booster': None,
#  'callbacks': None,
#  'colsample_bylevel': None,
#  'colsample_bynode': None,
#  'colsample_bytree': 0.5,
#  'device': None,
#  'early_stopping_rounds': None,
#  'enable_categorical': False,
#  'eval_metric': None,
#  'feature_types': None,
#  'gamma': None,
#  'grow_policy': None,
#  'importance_type': None,
#  'interaction_constraints': None,
#  'learning_rate': 0.01,
#  'max_bin': None,
#  'max_cat_threshold': None,
#  'max_cat_to_onehot': None,
#  'max_delta_step': None,
#  'max_depth': 3,
#  'max_leaves': None,
#  'min_child_weight': None,
#  'missing': nan,
#  'monotone_constraints': None,
#  'multi_strategy': None,
#  'n_estimators': 200,
#  'n_jobs': None,
#  'num_parallel_tree': None,
#  'random_state': None,
#  'reg_alpha': None,
#  'reg_lambda': None,
#  'sampling_method': None,
#  'scale_pos_weight': None,
#  'subsample': 0.5,
#  'tree_method': None,
#  'validate_parameters': None,
#  'verbosity': None}

# %%
model2.fit(X_train, y_train)
y_pred = model2.predict(X_test)
# accuracy = accuracy_score(y_test, y_pred)
# print("Accuracy:", accuracy)

# %%
from sklearn.metrics import precision_score, recall_score, f1_score

precision = precision_score(y_test, y_pred, average='macro')
recall = recall_score(y_test, y_pred, average='macro')
f1 = f1_score(y_test, y_pred, average='macro')

print("Precision:", precision)
print("Recall:", recall)
print("F1-score:", f1)
# Out:
# Precision: 0.9970853206147323
# Recall: 0.9851145721446474
# F1-score: 0.9907775400794966

# %%
from sklearn.metrics import roc_curve, auc
import numpy as np

num_classes = len(np.unique(y_test))

y_probs = model2.predict_proba(X_test)
# Compute ROC curve and AUC for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(num_classes):  # num_classes is the number of classes in your classification
    fpr[i], tpr[i], _ = roc_curve(y_test == i, y_probs[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Plot ROC curves for each class
plt.figure(figsize=(8, 6))
for i in range(num_classes):
    plt.plot(fpr[i], tpr[i], lw=2, label='ROC curve (area = %0.2f) for class %d' % (roc_auc[i], i))
plt.plot([0, 1], [0, 1], color='red', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve for Multiclass')
plt.legend(loc="lower right")
plt.show()
